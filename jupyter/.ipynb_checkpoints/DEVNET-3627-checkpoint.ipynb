# %% [markdown]
# # DEVNET-3627: Make Python applications faster with asyncio!
#
# ## Demo 1: Sequential SSH to network devices with netmiko

# %%
import time
import sys
from pprint import pprint
from typing import Any, Dict, Iterable

from netmiko import ConnectHandler

from utils import get_devices_conn_params

COMMANDS = ['show platform software status control-processor brief', 'show arp']
devices_conn_info = get_devices_conn_params()
num_devices = len(devices_conn_info)

def get_commands_output(device_conn_params: Dict[str, str], commands: Iterable[str]) -> Dict[str, str]:
    """Collects a list of outputs from device and returns them as dict, where command is the key"""
    result: Dict[str, str] = {}
    with ConnectHandler(**device_conn_params) as device_conn:
        for command in commands:
            cli_output = device_conn.send_command(command)
            result[command] = cli_output
    return result

# %% [markdown]
# Let's get SSH connection details, collect outputs for every device and print them:

# %%
start_time = time.time()

for device, device_conn_params in devices_conn_info.items():
    device_commands_output = get_commands_output(device_conn_params, COMMANDS)
    print(f"====== Outputs from {device} =======")
    for command, output in device_commands_output.items():
        print(f"output for the command **{command}**:\n{output}\n")

time_to_run = time.time() - start_time
num_devices = len(devices_conn_info)
print(f"It took {time_to_run:.2f} seconds to run for {num_devices} devices")
# Out:
# ====== Outputs from R1 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.65   0.67   0.71
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2593620 (86%)   425316 (14%)   3181900 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  14.14   9.43   0.00  76.26   0.00   0.14   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.12.1             -   fa16.3ed6.768b  ARPA   GigabitEthernet3
# Internet  100.64.12.2           230   fa16.3eab.de82  ARPA   GigabitEthernet3
# Internet  100.64.14.1             -   fa16.3ee5.6002  ARPA   GigabitEthernet4
# Internet  100.64.14.4           217   fa16.3e4b.cfbb  ARPA   GigabitEthernet4
# Internet  100.65.1.1              -   fa16.3e70.284c  ARPA   GigabitEthernet2
# Internet  100.65.1.11             0   Incomplete      ARPA
# Internet  192.168.1.1             -   001e.f6fc.96bd  ARPA   VirtualPortGroup0
#
# ====== Outputs from R2 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.85   0.80   0.82
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2593092 (86%)   425844 (14%)   3187084 (106%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  16.29   8.42   0.00  75.13   0.00   0.14   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.12.1           230   fa16.3ed6.768b  ARPA   GigabitEthernet2
# Internet  100.64.12.2             -   fa16.3eab.de82  ARPA   GigabitEthernet2
# Internet  100.64.23.2             -   fa16.3e1a.b817  ARPA   GigabitEthernet3
# Internet  100.64.23.3           200   fa16.3e24.505f  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.bde1.e8bd  ARPA   VirtualPortGroup0
#
# ====== Outputs from R3 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.80   0.82   0.89
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2573664 (85%)   445272 (15%)   3180064 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  12.82   9.20   0.00  77.82   0.00   0.14   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.23.2           200   fa16.3e1a.b817  ARPA   GigabitEthernet2
# Internet  100.64.23.3             -   fa16.3e24.505f  ARPA   GigabitEthernet2
# Internet  100.65.3.3              -   fa16.3eeb.6422  ARPA   GigabitEthernet3
# Internet  100.65.3.6            190   fa16.3e84.02f5  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.bdba.9abd  ARPA   VirtualPortGroup0
#
# ====== Outputs from R4 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.73   0.82   0.81
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Warning  3018936  2702152 (90%)   316784 (10%)   3179620 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  16.88   8.68   0.00  74.32   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.14.1           217   fa16.3ee5.6002  ARPA   GigabitEthernet2
# Internet  100.64.14.4             -   fa16.3e4b.cfbb  ARPA   GigabitEthernet2
# Internet  100.64.45.4             -   fa16.3e92.01ba  ARPA   GigabitEthernet3
# Internet  100.64.45.5           194   fa16.3efa.c07c  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.f6b2.0ebd  ARPA   VirtualPortGroup0
#
# ====== Outputs from R5 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.77   0.84   0.89
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2584792 (86%)   434144 (14%)   3180936 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  16.71   8.31   0.00  74.79   0.00   0.16   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.45.4           195   fa16.3e92.01ba  ARPA   GigabitEthernet2
# Internet  100.64.45.5             -   fa16.3efa.c07c  ARPA   GigabitEthernet2
# Internet  100.65.2.5              -   fa16.3efb.f8bc  ARPA   GigabitEthernet3
# Internet  100.65.2.6            218   fa16.3e6c.dc27  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.e533.f7bd  ARPA   VirtualPortGroup0
#
# ====== Outputs from R6 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.83   0.89   0.98
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Warning  3018936  2696372 (89%)   322564 (11%)   3178912 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  17.75   7.60   0.00  74.53   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.65.2.5            218   fa16.3efb.f8bc  ARPA   GigabitEthernet2
# Internet  100.65.2.6              -   fa16.3e6c.dc27  ARPA   GigabitEthernet2
# Internet  100.65.3.3            191   fa16.3eeb.6422  ARPA   GigabitEthernet3
# Internet  100.65.3.6              -   fa16.3e84.02f5  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.bda6.f2bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.101          -   fa16.3e96.3f7d  ARPA   GigabitEthernet5
# Internet  198.51.100.102        218   fa16.3e6a.0d0c  ARPA   GigabitEthernet5
# Internet  198.51.100.105          -   fa16.3e34.b5d4  ARPA   GigabitEthernet4
# Internet  198.51.100.106        195   fa16.3eba.e03c  ARPA   GigabitEthernet4
#
# ====== Outputs from R7 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   1.14   1.08   1.03
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2612288 (87%)   406648 (13%)   3184524 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  18.48   9.78   0.00  71.62   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.14f8.43bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.105        196   fa16.3e34.b5d4  ARPA   GigabitEthernet2
# Internet  198.51.100.106          -   fa16.3eba.e03c  ARPA   GigabitEthernet2
# Internet  198.51.100.113          -   fa16.3e68.493d  ARPA   GigabitEthernet3
# Internet  198.51.100.114        197   fa16.3e65.ce99  ARPA   GigabitEthernet3
#
# ====== Outputs from R8 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.98   1.07   1.09
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2625276 (87%)   393660 (13%)   3192104 (106%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  14.40  10.51   0.00  74.97   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.f6a7.7ebd  ARPA   VirtualPortGroup0
# Internet  198.51.100.101        218   fa16.3e96.3f7d  ARPA   GigabitEthernet2
# Internet  198.51.100.102          -   fa16.3e6a.0d0c  ARPA   GigabitEthernet2
# Internet  198.51.100.109          -   fa16.3e18.6ed4  ARPA   GigabitEthernet3
# Internet  198.51.100.110         10   fa16.3efe.fd67  ARPA   GigabitEthernet3
# ====== Outputs from R9 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.68   0.73   0.78
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2618096 (87%)   400840 (13%)   3182280 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  15.16   7.33   0.00  77.41   0.00   0.08   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.7a3f.01bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.113        197   fa16.3e68.493d  ARPA   GigabitEthernet2
# Internet  198.51.100.114          -   fa16.3e65.ce99  ARPA   GigabitEthernet2
#
# ====== Outputs from R10 =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.67   1.64   1.71
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2635352 (87%)   383584 (13%)   3174476 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  15.74   7.70   0.00  76.44   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.bdad.babd  ARPA   VirtualPortGroup0
# Internet  198.51.100.109         11   fa16.3e18.6ed4  ARPA   GigabitEthernet2
# Internet  198.51.100.110          -   fa16.3efe.fd67  ARPA   GigabitEthernet2
#
# It took 122.06 seconds to run for 10 devices

# %% [markdown]
# ## Demo 2: Connect to devices via SSH using netmiko and threading

# %%
from concurrent.futures import ThreadPoolExecutor
from functools import partial

def get_commands_output(device_conn_params: Dict[str, str], commands: Iterable[str]) -> Dict[str, str]:
    """Collects a list of outputs from device and returns them as dict, where command is the key"""
    result: Dict[str, str] = {}
    with ConnectHandler(**device_conn_params) as device_conn:
        for command in commands:
            cli_output = device_conn.send_command(command)
            result[command] = cli_output
    return result

worker = partial(get_commands_output, commands=COMMANDS)
start_time = time.time()

with ThreadPoolExecutor(max_workers=10) as pool:
    results = pool.map(worker, devices_conn_info.values())
    
for hostname, result in zip(devices_conn_info, results):
    print(f"====== Outputs from device {hostname} were collected =======")
    for command, output in result.items():
        print(f"output for the command **{command}**:\n{output}\n")
    

time_to_run = time.time() - start_time
print(f"It took {time_to_run:.2f} seconds to run for {num_devices} devices")
# Out:
# ====== Outputs from device R1 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.86   0.73   0.74
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2593748 (86%)   425188 (14%)   3181900 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  12.79   8.04   0.00  78.99   0.00   0.16   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.12.1             -   fa16.3ed6.768b  ARPA   GigabitEthernet3
# Internet  100.64.12.2           232   fa16.3eab.de82  ARPA   GigabitEthernet3
# Internet  100.64.14.1             -   fa16.3ee5.6002  ARPA   GigabitEthernet4
# Internet  100.64.14.4           219   fa16.3e4b.cfbb  ARPA   GigabitEthernet4
# Internet  100.65.1.1              -   fa16.3e70.284c  ARPA   GigabitEthernet2
# Internet  100.65.1.11             0   Incomplete      ARPA
# Internet  192.168.1.1             -   001e.f6fc.96bd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R2 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.83   0.79   0.81
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2593092 (86%)   425844 (14%)   3187084 (106%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  15.73   7.79   0.00  76.38   0.00   0.08   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.12.1           232   fa16.3ed6.768b  ARPA   GigabitEthernet2
# Internet  100.64.12.2             -   fa16.3eab.de82  ARPA   GigabitEthernet2
# Internet  100.64.23.2             -   fa16.3e1a.b817  ARPA   GigabitEthernet3
# Internet  100.64.23.3           202   fa16.3e24.505f  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.bde1.e8bd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R3 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.81   0.82   0.89
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2573644 (85%)   445292 (15%)   3180064 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  11.55   8.87   0.00  79.44   0.00   0.12   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.23.2           202   fa16.3e1a.b817  ARPA   GigabitEthernet2
# Internet  100.64.23.3             -   fa16.3e24.505f  ARPA   GigabitEthernet2
# Internet  100.65.3.3              -   fa16.3eeb.6422  ARPA   GigabitEthernet3
# Internet  100.65.3.6            192   fa16.3e84.02f5  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.bdba.9abd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R4 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.77   0.80   0.81
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Warning  3018936  2702140 (90%)   316796 (10%)   3179620 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  16.27   8.31   0.00  75.28   0.00   0.12   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.14.1           219   fa16.3ee5.6002  ARPA   GigabitEthernet2
# Internet  100.64.14.4             -   fa16.3e4b.cfbb  ARPA   GigabitEthernet2
# Internet  100.64.45.4             -   fa16.3e92.01ba  ARPA   GigabitEthernet3
# Internet  100.64.45.5           196   fa16.3efa.c07c  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.f6b2.0ebd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R5 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.65   0.80   0.88
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2584748 (86%)   434188 (14%)   3180936 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  16.39   7.96   0.00  75.53   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.45.4           196   fa16.3e92.01ba  ARPA   GigabitEthernet2
# Internet  100.64.45.5             -   fa16.3efa.c07c  ARPA   GigabitEthernet2
# Internet  100.65.2.5              -   fa16.3efb.f8bc  ARPA   GigabitEthernet3
# Internet  100.65.2.6            220   fa16.3e6c.dc27  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.e533.f7bd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R6 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.81   0.88   0.98
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Warning  3018936  2696248 (89%)   322688 (11%)   3178912 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  18.58   7.90   0.00  73.38   0.00   0.12   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.65.2.5            219   fa16.3efb.f8bc  ARPA   GigabitEthernet2
# Internet  100.65.2.6              -   fa16.3e6c.dc27  ARPA   GigabitEthernet2
# Internet  100.65.3.3            192   fa16.3eeb.6422  ARPA   GigabitEthernet3
# Internet  100.65.3.6              -   fa16.3e84.02f5  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.bda6.f2bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.101          -   fa16.3e96.3f7d  ARPA   GigabitEthernet5
# Internet  198.51.100.102        219   fa16.3e6a.0d0c  ARPA   GigabitEthernet5
# Internet  198.51.100.105          -   fa16.3e34.b5d4  ARPA   GigabitEthernet4
# Internet  198.51.100.106        196   fa16.3eba.e03c  ARPA   GigabitEthernet4
#
# ====== Outputs from device R7 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.94   1.04   1.01
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2612288 (87%)   406648 (13%)   3184524 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  20.20  10.07   0.00  69.61   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.14f8.43bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.105        196   fa16.3e34.b5d4  ARPA   GigabitEthernet2
# Internet  198.51.100.106          -   fa16.3eba.e03c  ARPA   GigabitEthernet2
# Internet  198.51.100.113          -   fa16.3e68.493d  ARPA   GigabitEthernet3
# Internet  198.51.100.114        197   fa16.3e65.ce99  ARPA   GigabitEthernet3
#
# ====== Outputs from device R8 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   1.28   1.13   1.10
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2625276 (87%)   393660 (13%)   3192104 (106%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  14.12  10.55   0.00  75.13   0.00   0.19   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.f6a7.7ebd  ARPA   VirtualPortGroup0
# Internet  198.51.100.101        219   fa16.3e96.3f7d  ARPA   GigabitEthernet2
# Internet  198.51.100.102          -   fa16.3e6a.0d0c  ARPA   GigabitEthernet2
# Internet  198.51.100.109          -   fa16.3e18.6ed4  ARPA   GigabitEthernet3
# Internet  198.51.100.110         11   fa16.3efe.fd67  ARPA   GigabitEthernet3
#
# ====== Outputs from device R9 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.68   0.73   0.78
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2618096 (87%)   400840 (13%)   3182280 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  15.16   7.33   0.00  77.41   0.00   0.08   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.7a3f.01bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.113        197   fa16.3e68.493d  ARPA   GigabitEthernet2
# Internet  198.51.100.114          -   fa16.3e65.ce99  ARPA   GigabitEthernet2
#
# ====== Outputs from device R10 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.64   1.44   1.63
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2636668 (87%)   382268 (13%)   3174476 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  18.35   8.71   0.00  72.74   0.00   0.12   0.06
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.bdad.babd  ARPA   VirtualPortGroup0
# Internet  198.51.100.109         11   fa16.3e18.6ed4  ARPA   GigabitEthernet2
# Internet  198.51.100.110          -   fa16.3efe.fd67  ARPA   GigabitEthernet2
#
# It took 19.48 seconds to run for 10 devices

# %% [markdown]
# ## Demo 2b: Connect to devices via SSH using netmiko and threading (racing condition)

# %%
def get_commands_output_broken(device_conn_params: Dict[str, str], commands: Iterable[str]) -> Dict[str, str]:
    """Collects a list of outputs from device and returns them as dict, where command is the key
    
    Broken version with racing condition
    """
    result: Dict[str, str] = {}
    with ConnectHandler(**device_conn_params) as device_conn:
        for command in commands:
            cli_output = device_conn.send_command(command)
            first_three_lines = '\n'.join(cli_output.splitlines()[:3])
            print(f"{device_conn_params['host']} - {command}:\n{first_three_lines}")
            result[command] = cli_output
    return result

worker = partial(get_commands_output_broken, commands=COMMANDS)
start_time = time.time()

with ThreadPoolExecutor(max_workers=10) as pool:
    pool.map(worker, devices_conn_info.values())
    
time_to_run = time.time() - start_time
print(f"It took {time_to_run:.2f} seconds to run for {num_devices} devices")
# Out:
# 198.18.1.107 - show platform software status control-processor brief:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.94   1.04   1.01
# 198.18.1.107 - show arp:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.14f8.43bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.105        197   fa16.3e34.b5d4  ARPA   GigabitEthernet2
# 198.18.1.108 - show platform software status control-processor brief:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   1.28   1.13   1.10
# 198.18.1.110 - show platform software status control-processor brief:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.64   1.44   1.63
# 198.18.1.103 - show platform software status control-processor brief:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.81   0.82   0.89
# 198.18.1.102 - show platform software status control-processor brief:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.83   0.79   0.81
# 198.18.1.104 - show platform software status control-processor brief:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.77   0.80   0.81
# 198.18.1.106 - show platform software status control-processor brief:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.87   0.89   0.98
# 198.18.1.110 - show arp:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.bdad.babd  ARPA   VirtualPortGroup0
# Internet  198.51.100.109         11   fa16.3e18.6ed4  ARPA   GigabitEthernet2
# 198.18.1.109 - show platform software status control-processor brief:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.68   0.72   0.77
# 198.18.1.102 - show arp:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.12.1           232   fa16.3ed6.768b  ARPA   GigabitEthernet2
# Internet  100.64.12.2             -   fa16.3eab.de82  ARPA   GigabitEthernet2
# 198.18.1.104 - show arp:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.14.1           219   fa16.3ee5.6002  ARPA   GigabitEthernet2
# Internet  100.64.14.4             -   fa16.3e4b.cfbb  ARPA   GigabitEthernet2
# 198.18.1.106 - show arp:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.65.2.5            220   fa16.3efb.f8bc  ARPA   GigabitEthernet2
# Internet  100.65.2.6              -   fa16.3e6c.dc27  ARPA   GigabitEthernet2
# 198.18.1.109 - show arp:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.7a3f.01bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.113        198   fa16.3e68.493d  ARPA   GigabitEthernet2
# 198.18.1.108 - show arp:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.f6a7.7ebd  ARPA   VirtualPortGroup0
# Internet  198.51.100.101        219   fa16.3e96.3f7d  ARPA   GigabitEthernet2
# 198.18.1.101 - show platform software status control-processor brief:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.86   0.73   0.74
# 198.18.1.103 - show arp:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.23.2           202   fa16.3e1a.b817  ARPA   GigabitEthernet2
# Internet  100.64.23.3             -   fa16.3e24.505f  ARPA   GigabitEthernet2
# 198.18.1.101 - show arp:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.12.1             -   fa16.3ed6.768b  ARPA   GigabitEthernet3
# Internet  100.64.12.2           232   fa16.3eab.de82  ARPA   GigabitEthernet3
# It took 18.35 seconds to run for 10 devices

# %% [markdown]
# ## Demo 3: asyncio building blocks

# %%
import asyncio
import random
from datetime import datetime

async def greet_cisco_live(num):
    seconds_to_sleep = random.randint(1, 5)
    await asyncio.sleep(seconds_to_sleep)
    cur_time = datetime.now().strftime("%H:%M:%S.%f")
    print(
        f"{cur_time}: Hello CLUS! My number is {num} and "
        f"I've been waiting {seconds_to_sleep} seconds to tell you that!"
    )

    
loop = asyncio.get_event_loop()

tasks = [
    loop.create_task(greet_cisco_live(num))
    for num in range(10)
]

start_time = datetime.now().strftime("%H:%M:%S.%f")
print(f"{start_time}: Started")
_ = loop.run_until_complete(asyncio.wait(tasks))
# Out:
# 12:41:51.305595: started
# 12:41:52.309165: Hello CLUS! My number is 8 and I've been waiting 1 seconds to tell you that!
# 12:41:53.309206: Hello CLUS! My number is 0 and I've been waiting 2 seconds to tell you that!
# 12:41:53.309396: Hello CLUS! My number is 4 and I've been waiting 2 seconds to tell you that!
# 12:41:54.308465: Hello CLUS! My number is 1 and I've been waiting 3 seconds to tell you that!
# 12:41:54.308678: Hello CLUS! My number is 2 and I've been waiting 3 seconds to tell you that!
# 12:41:54.308742: Hello CLUS! My number is 5 and I've been waiting 3 seconds to tell you that!
# 12:41:54.308796: Hello CLUS! My number is 6 and I've been waiting 3 seconds to tell you that!
# 12:41:56.310142: Hello CLUS! My number is 3 and I've been waiting 5 seconds to tell you that!
# 12:41:56.310300: Hello CLUS! My number is 7 and I've been waiting 5 seconds to tell you that!
# 12:41:56.310343: Hello CLUS! My number is 9 and I've been waiting 5 seconds to tell you that!

# %% [markdown]
# ## Demo 4: asyncio SSH using netdev

# %%
import asyncio
import netdev

def get_commands_output(device_conn_params: Dict[str, str], commands: Iterable[str]) -> Dict[str, str]:
    """Collects a list of outputs from device and returns them as dict, where command is the key"""
    result: Dict[str, str] = {}
    with ConnectHandler(**device_conn_params) as device_conn:
        for command in commands:
            cli_output = device_conn.send_command(command)
            result[command] = cli_output
    return result

async def async_get_commands_output(device_conn_params: Dict[str, str], commands: Iterable[str]) -> Dict[str, str]:
    """Collect a list of outputs from device and returns them as dict, where the command is the key
    
    Runs asynchronously
    """
    result: Dict[str, str] = {}
    async with netdev.create(**device_conn_params) as device_conn:
        for command in commands:
            cli_output = await device_conn.send_command(command)
            result[command] = cli_output
    return result

loop = asyncio.get_event_loop()

start_time = time.time()

tasks = [
    loop.create_task(async_get_commands_output(device_conn_params, COMMANDS))
    for device_conn_params in devices_conn_info.values()
]

loop.run_until_complete(asyncio.wait(tasks))

for hostname, task in zip(devices_conn_info, tasks):
    print(f"====== Outputs from device {hostname} were collected =======")
    for command, output in task.result().items():
        print(f"output for the command **{command}**:\n{output}\n")

time_to_run = time.time() - start_time
print(f"It took {time_to_run:.2f} seconds to run for {num_devices} devices")
# Out:
# ====== Outputs from device R1 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.69   0.78   0.79
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2592916 (86%)   426020 (14%)   3169580 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  11.91   7.67   0.00  80.32   0.00   0.08   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.12.1             -   fa16.3ed6.768b  ARPA   GigabitEthernet3
# Internet  100.64.12.2           241   fa16.3eab.de82  ARPA   GigabitEthernet3
# Internet  100.64.14.1             -   fa16.3ee5.6002  ARPA   GigabitEthernet4
# Internet  100.64.14.4           228   fa16.3e4b.cfbb  ARPA   GigabitEthernet4
# Internet  100.65.1.1              -   fa16.3e70.284c  ARPA   GigabitEthernet2
# Internet  192.168.1.1             -   001e.f6fc.96bd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R2 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.76   0.78   0.81
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2592260 (86%)   426676 (14%)   3187084 (106%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  15.32   7.50   0.00  77.08   0.00   0.08   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.12.1           241   fa16.3ed6.768b  ARPA   GigabitEthernet2
# Internet  100.64.12.2             -   fa16.3eab.de82  ARPA   GigabitEthernet2
# Internet  100.64.23.2             -   fa16.3e1a.b817  ARPA   GigabitEthernet3
# Internet  100.64.23.3           211   fa16.3e24.505f  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.bde1.e8bd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R3 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.81   0.77   0.83
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2572928 (85%)   446008 (15%)   3179740 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  11.47   8.29   0.00  80.13   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.23.2           212   fa16.3e1a.b817  ARPA   GigabitEthernet2
# Internet  100.64.23.3             -   fa16.3e24.505f  ARPA   GigabitEthernet2
# Internet  100.65.3.3              -   fa16.3eeb.6422  ARPA   GigabitEthernet3
# Internet  100.65.3.6            201   fa16.3e84.02f5  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.bdba.9abd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R4 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.73   0.81   0.82
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Warning  3018936  2701304 (89%)   317632 (11%)   3179620 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  15.60   8.10   0.00  76.18   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.14.1           228   fa16.3ee5.6002  ARPA   GigabitEthernet2
# Internet  100.64.14.4             -   fa16.3e4b.cfbb  ARPA   GigabitEthernet2
# Internet  100.64.45.4             -   fa16.3e92.01ba  ARPA   GigabitEthernet3
# Internet  100.64.45.5           205   fa16.3efa.c07c  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.f6b2.0ebd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R5 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.75   0.81   0.88
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2583916 (86%)   435020 (14%)   3168692 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  15.55   7.41   0.00  76.90   0.00   0.12   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.64.45.4           205   fa16.3e92.01ba  ARPA   GigabitEthernet2
# Internet  100.64.45.5             -   fa16.3efa.c07c  ARPA   GigabitEthernet2
# Internet  100.65.2.5              -   fa16.3efb.f8bc  ARPA   GigabitEthernet3
# Internet  100.65.2.6            229   fa16.3e6c.dc27  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.e533.f7bd  ARPA   VirtualPortGroup0
#
# ====== Outputs from device R6 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.97   0.89   0.93
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Warning  3018936  2695364 (89%)   323572 (11%)   3177400 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  18.23   7.38   0.00  74.24   0.00   0.12   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  100.65.2.5            229   fa16.3efb.f8bc  ARPA   GigabitEthernet2
# Internet  100.65.2.6              -   fa16.3e6c.dc27  ARPA   GigabitEthernet2
# Internet  100.65.3.3            201   fa16.3eeb.6422  ARPA   GigabitEthernet3
# Internet  100.65.3.6              -   fa16.3e84.02f5  ARPA   GigabitEthernet3
# Internet  192.168.1.1             -   001e.bda6.f2bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.101          -   fa16.3e96.3f7d  ARPA   GigabitEthernet5
# Internet  198.51.100.102        229   fa16.3e6a.0d0c  ARPA   GigabitEthernet5
# Internet  198.51.100.105          -   fa16.3e34.b5d4  ARPA   GigabitEthernet4
# Internet  198.51.100.106        206   fa16.3eba.e03c  ARPA   GigabitEthernet4
#
# ====== Outputs from device R7 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.70   0.91   0.97
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2611276 (86%)   407660 (14%)   3172524 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  17.73   9.79   0.00  72.37   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.14f8.43bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.105        206   fa16.3e34.b5d4  ARPA   GigabitEthernet2
# Internet  198.51.100.106          -   fa16.3eba.e03c  ARPA   GigabitEthernet2
# Internet  198.51.100.113          -   fa16.3e68.493d  ARPA   GigabitEthernet3
# Internet  198.51.100.114        207   fa16.3e65.ce99  ARPA   GigabitEthernet3
#
# ====== Outputs from device R8 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   1.29   1.06   1.06
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2624512 (87%)   394424 (13%)   3192480 (106%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  13.45  10.36   0.00  76.07   0.00   0.10   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.f6a7.7ebd  ARPA   VirtualPortGroup0
# Internet  198.51.100.101        229   fa16.3e96.3f7d  ARPA   GigabitEthernet2
# Internet  198.51.100.102          -   fa16.3e6a.0d0c  ARPA   GigabitEthernet2
# Internet  198.51.100.109          -   fa16.3e18.6ed4  ARPA   GigabitEthernet3
# Internet  198.51.100.110         20   fa16.3efe.fd67  ARPA   GigabitEthernet3
#
# ====== Outputs from device R9 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.70   0.70   0.75
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2617212 (87%)   401724 (13%)   3182052 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  14.87   7.61   0.00  77.42   0.00   0.08   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.7a3f.01bd  ARPA   VirtualPortGroup0
# Internet  198.51.100.113        207   fa16.3e68.493d  ARPA   GigabitEthernet2
# Internet  198.51.100.114          -   fa16.3e65.ce99  ARPA   GigabitEthernet2
#
# ====== Outputs from device R10 were collected =======
# output for the command **show platform software status control-processor brief**:
# Load Average
#  Slot  Status  1-Min  5-Min 15-Min
#   RP0 Healthy   0.64   0.88   1.26
#
# Memory (kB)
#  Slot  Status    Total     Used (Pct)     Free (Pct) Committed (Pct)
#   RP0 Healthy  3018936  2584448 (86%)   434488 (14%)   3173076 (105%)
#
# CPU Utilization
#  Slot  CPU   User System   Nice   Idle    IRQ   SIRQ IOwait
#   RP0    0  12.96   6.91   0.00  80.04   0.00   0.08   0.00
#
#
# output for the command **show arp**:
# Protocol  Address          Age (min)  Hardware Addr   Type   Interface
# Internet  192.168.1.1             -   001e.bdad.babd  ARPA   VirtualPortGroup0
# Internet  198.51.100.109         21   fa16.3e18.6ed4  ARPA   GigabitEthernet2
# Internet  198.51.100.110          -   fa16.3efe.fd67  ARPA   GigabitEthernet2
#
# It took 10.59 seconds to run for 10 devices

# %% [markdown]
# ## Demo 5: asyncio REST using aiohttp

# %%
import asyncio
import aiohttp

RESTCONF_ROOT = "https://{host}/restconf/data"
RESTCONF_MEMORY_STATS_ENDPOINT = "/cisco-platform-software/control-processes/control-process=platform-fru-rp,0,0,-1/memory-stats"
HEADERS = {"Accept": "application/yang-data+json", "Content-Type": "application/yang-data+json"}

async def get_memory_stats(device_conn_params: Dict[str, str]) -> Dict[str, str]:
    """Collect memory stats from the device using RESTCONF"""
    async with aiohttp.ClientSession() as session:
        host = device_conn_params["host"]
        username = device_conn_params["username"]
        password = device_conn_params["password"]
        url = (RESTCONF_ROOT + RESTCONF_MEMORY_STATS_ENDPOINT).format(host=host)
        async with session.get(
            url,
            headers=HEADERS,
            auth=aiohttp.BasicAuth(username, password),
            ssl=False,
        ) as response:
            return await response.json()

loop = asyncio.get_event_loop()

start_time = time.time()

tasks = [
    loop.create_task(get_memory_stats(device_conn_params))
    for device_conn_params in devices_conn_info.values()
]

loop.run_until_complete(asyncio.wait(tasks))

for hostname, task in zip(devices_conn_info, tasks):
    print(f"====== Memory stats on {hostname} =======")
    pprint(task.result())

time_to_run = time.time() - start_time
print(f"It took {time_to_run:.2f} seconds to run for {num_devices} devices")
# Out:
# ====== Memory stats on R1 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '426016',
#                                                       'available-percent': '14',
#                                                       'committed-number': '3169580',
#                                                       'committed-percent': 105,
#                                                       'free-number': '426016',
#                                                       'free-percent': '14',
#                                                       'memory-status': 'Healthy',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2592920',
#                                                       'used-percent': '86'}}
# ====== Memory stats on R2 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '426676',
#                                                       'available-percent': '14',
#                                                       'committed-number': '3187084',
#                                                       'committed-percent': 106,
#                                                       'free-number': '426676',
#                                                       'free-percent': '14',
#                                                       'memory-status': 'Healthy',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2592260',
#                                                       'used-percent': '86'}}
# ====== Memory stats on R3 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '446004',
#                                                       'available-percent': '15',
#                                                       'committed-number': '3179740',
#                                                       'committed-percent': 105,
#                                                       'free-number': '446004',
#                                                       'free-percent': '15',
#                                                       'memory-status': 'Healthy',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2572932',
#                                                       'used-percent': '85'}}
# ====== Memory stats on R4 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '317628',
#                                                       'available-percent': '11',
#                                                       'committed-number': '3179620',
#                                                       'committed-percent': 105,
#                                                       'free-number': '317628',
#                                                       'free-percent': '11',
#                                                       'memory-status': 'Warning',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2701308',
#                                                       'used-percent': '89'}}
# ====== Memory stats on R5 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '435016',
#                                                       'available-percent': '14',
#                                                       'committed-number': '3168692',
#                                                       'committed-percent': 105,
#                                                       'free-number': '435016',
#                                                       'free-percent': '14',
#                                                       'memory-status': 'Healthy',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2583920',
#                                                       'used-percent': '86'}}
# ====== Memory stats on R6 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '323572',
#                                                       'available-percent': '11',
#                                                       'committed-number': '3177400',
#                                                       'committed-percent': 105,
#                                                       'free-number': '323572',
#                                                       'free-percent': '11',
#                                                       'memory-status': 'Warning',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2695364',
#                                                       'used-percent': '89'}}
# ====== Memory stats on R7 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '407660',
#                                                       'available-percent': '14',
#                                                       'committed-number': '3172524',
#                                                       'committed-percent': 105,
#                                                       'free-number': '407660',
#                                                       'free-percent': '14',
#                                                       'memory-status': 'Healthy',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2611276',
#                                                       'used-percent': '86'}}
# ====== Memory stats on R8 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '394424',
#                                                       'available-percent': '13',
#                                                       'committed-number': '3192480',
#                                                       'committed-percent': 106,
#                                                       'free-number': '394424',
#                                                       'free-percent': '13',
#                                                       'memory-status': 'Healthy',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2624512',
#                                                       'used-percent': '87'}}
# ====== Memory stats on R9 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '401724',
#                                                       'available-percent': '13',
#                                                       'committed-number': '3182052',
#                                                       'committed-percent': 105,
#                                                       'free-number': '401724',
#                                                       'free-percent': '13',
#                                                       'memory-status': 'Healthy',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2617212',
#                                                       'used-percent': '87'}}
# ====== Memory stats on R10 =======
# {'Cisco-IOS-XE-platform-software-oper:memory-stats': {'available-number': '434488',
#                                                       'available-percent': '14',
#                                                       'committed-number': '3173076',
#                                                       'committed-percent': 105,
#                                                       'free-number': '434488',
#                                                       'free-percent': '14',
#                                                       'memory-status': 'Healthy',
#                                                       'status': {'critical-threshold-percent': 93,
#                                                                  'warning-threshold-percent': 88},
#                                                       'total': '3018936',
#                                                       'used-number': '2584448',
#                                                       'used-percent': '86'}}
# It took 2.07 seconds to run for 10 devices

# %% [markdown]
# ## Demo 6: Check cabling using asyncio and netdev

# %%
import asyncio
import csv
import sys

import netdev
from deepdiff import DeepDiff
from ruamel.yaml import YAML

from constants import (
    TOPOLOGY_FILE,
    CDP_COMMAND,
)
from utils import parse_show_cdp_neighbors, normalize_interface_name

yaml = YAML()

def parse_device_cabling():
    """Parses topology csv file and gets cabling details"""
    result: Dict[str, Dict[str, str]] = {}
    with open(TOPOLOGY_FILE, "r") as f:
        reader = csv.DictReader(f)
        for row in reader:
            device_name = row["local_hostname"]
            
            if device_name in result:
                device = result[device_name]
            else:
                device = {}
                result[device_name] = device
                
            local_port = normalize_interface_name(row["local_port"])
                
            local_port_dict = {
                "connected_device": {
                    "name": row["remote_hostname"],
                    "port": normalize_interface_name(row["remote_port"]),
                }
            }
            device[local_port] = local_port_dict
            
    return result


async def get_device_neighbors(device_params: Dict[str, str]) -> Dict[str, Dict[str, Any]]:
    """Checks cabling using CDP"""
    async with netdev.create(**device_params) as device_conn:
        show_cdp_neighbor_output = await device_conn.send_command(CDP_COMMAND)
        return parse_show_cdp_neighbors(show_cdp_neighbor_output)

# %%
start_time = time.time()

desired_cabling = parse_device_cabling()

loop = asyncio.get_event_loop()

tasks = []
for device_params in devices_conn_info.values():
    tasks.append(loop.create_task(get_device_neighbors(device_params)))

loop.run_until_complete(asyncio.wait(tasks))

existing_cabling = {}
for hostname, task in zip(devices_conn_info, tasks):
    existing_cabling[hostname] = task.result()

time_to_run = time.time() - start_time
num_devices = len(devices_conn_info)
print(f"It took {time_to_run:.2f} seconds to run for {num_devices} devices")    
    
cabling_errors = DeepDiff(desired_cabling, existing_cabling)
cabling_errors_dict = dict(cabling_errors)
if cabling_errors:
    print("Some cabling errors have been found:")
    yaml.dump(cabling_errors_dict, sys.stdout)
else:
    print("Cabling 100% coincides with the documentation! Congratulations!\n")
    
print("======== Existing cabling ========")
pprint(existing_cabling)
print("\n======== Desired cabling ========")
pprint(desired_cabling)
# Out:
# It took 9.53 seconds to run for 10 devices
# Cabling 100% coincides with the documentation! Congratulations!
#
# Existing cabling:
# {'R1': {'GigabitEthernet3': {'connected_device': {'name': 'R2',
#                                                   'port': 'GigabitEthernet2'}},
#         'GigabitEthernet4': {'connected_device': {'name': 'R4',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R10': {'GigabitEthernet2': {'connected_device': {'name': 'R8',
#                                                    'port': 'GigabitEthernet3'}}},
#  'R2': {'GigabitEthernet2': {'connected_device': {'name': 'R1',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R3',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R3': {'GigabitEthernet2': {'connected_device': {'name': 'R2',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R6',
#                                                   'port': 'GigabitEthernet3'}}},
#  'R4': {'GigabitEthernet2': {'connected_device': {'name': 'R1',
#                                                   'port': 'GigabitEthernet4'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R5',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R5': {'GigabitEthernet2': {'connected_device': {'name': 'R4',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R6',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R6': {'GigabitEthernet2': {'connected_device': {'name': 'R5',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R3',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet4': {'connected_device': {'name': 'R7',
#                                                   'port': 'GigabitEthernet2'}},
#         'GigabitEthernet5': {'connected_device': {'name': 'R8',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R7': {'GigabitEthernet2': {'connected_device': {'name': 'R6',
#                                                   'port': 'GigabitEthernet4'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R9',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R8': {'GigabitEthernet2': {'connected_device': {'name': 'R6',
#                                                   'port': 'GigabitEthernet5'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R10',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R9': {'GigabitEthernet2': {'connected_device': {'name': 'R7',
#                                                   'port': 'GigabitEthernet3'}}}}
# Desired cabling:
# {'R1': {'GigabitEthernet3': {'connected_device': {'name': 'R2',
#                                                   'port': 'GigabitEthernet2'}},
#         'GigabitEthernet4': {'connected_device': {'name': 'R4',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R10': {'GigabitEthernet2': {'connected_device': {'name': 'R8',
#                                                    'port': 'GigabitEthernet3'}}},
#  'R2': {'GigabitEthernet2': {'connected_device': {'name': 'R1',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R3',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R3': {'GigabitEthernet2': {'connected_device': {'name': 'R2',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R6',
#                                                   'port': 'GigabitEthernet3'}}},
#  'R4': {'GigabitEthernet2': {'connected_device': {'name': 'R1',
#                                                   'port': 'GigabitEthernet4'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R5',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R5': {'GigabitEthernet2': {'connected_device': {'name': 'R4',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R6',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R6': {'GigabitEthernet2': {'connected_device': {'name': 'R5',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R3',
#                                                   'port': 'GigabitEthernet3'}},
#         'GigabitEthernet4': {'connected_device': {'name': 'R7',
#                                                   'port': 'GigabitEthernet2'}},
#         'GigabitEthernet5': {'connected_device': {'name': 'R8',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R7': {'GigabitEthernet2': {'connected_device': {'name': 'R6',
#                                                   'port': 'GigabitEthernet4'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R9',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R8': {'GigabitEthernet2': {'connected_device': {'name': 'R6',
#                                                   'port': 'GigabitEthernet5'}},
#         'GigabitEthernet3': {'connected_device': {'name': 'R10',
#                                                   'port': 'GigabitEthernet2'}}},
#  'R9': {'GigabitEthernet2': {'connected_device': {'name': 'R7',
#                                                   'port': 'GigabitEthernet3'}}}}

# %% [markdown]
# ## END
